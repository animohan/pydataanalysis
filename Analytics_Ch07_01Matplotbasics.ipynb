# %%
from pylab import *
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import math

# %matplotlib inline

plt.plot([1,2,3,4])
#plt.show()

# %%
#set the properties fof the plot
plt.plot([1,2,3,4],[1,4,9,16],"ro") #red dots

# %%
plt.axis([0,5,0,20]) #(0-5 x axis, 0-20 axis)
plt.title("The first plot") #title
plt.plot([1,2,3,4],[1,4,9,16],"ro") #red dots

# %%
t = np.arange(0,2.5,0.1)
y = list(map(math.sin, math.pi*t))
plt.plot(t,y)

# %%
t = np.arange(0,2.5,0.1)

y1 = list(map(math.sin, math.pi*t)) #apply math.sin function to all elements
                                # of math.pi*t
y2 = list(map(math.sin, math.pi*t+math.pi/2))
y3 = list(map(math.sin, math.pi*t-math.pi/2))
plt.plot(t, y1, 'b*', t, y2, 'g^',t, y3,'ys') #blue *, green tri, yellow sq

# %%
plt.plot(t, y1, 'b--', t, y2, 'g',t, y3,'r-.') 
# red -. , green solid and blue - -

# %%
plt.plot([1,2,4,2,1,0,1,2,1,4], linewidth =2.0) 
#specify line width

# %%
t = np.arange(0,5,0.1)
y1 = np.sin(2*np.pi*t)
y2 = np.sin(2*np.pi*t)
plt.subplot(211)
plt.plot(t,y1,'b-.')
plt.subplot(212)
plt.plot(t,y2, 'r--')
#subplot to divide the graph area (figure) into two areas
#argument to subplot:
    # how many parts figure is split into vertically
    # how many parts figure is split into horizontally
    #which subplot are we directing commands

# %%
plt.subplot(221)
plt.plot(t,y1,'b-.')
plt.subplot(222)
plt.plot(t,y2, 'r--')
plt.subplot(223)
plt.plot(t,y2, 'g')
plt.subplot(224)
plt.plot(t,y2, 'y.-')

# %%
plt.subplot(121)
plt.plot(t,y1,'b-.')
plt.subplot(122)
plt.plot(t,y2, 'r--')

# %%
#Adding text
